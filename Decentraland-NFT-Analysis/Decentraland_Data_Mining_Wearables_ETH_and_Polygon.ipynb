# %%
#Import all required libraries
import pandas as pd
import requests
import numpy as np
from datetime import datetime
import time
import matplotlib.pyplot as plt

# %%
def get_data(tscurrent, network):
    """This function posts a request to make an API call to Decentraland collections Subgraph URL
    parameters:
    ------------
    tscurrent: The timestamp to use in the query. The response will be the next 1000 sales after
    this timestamp. 
    network: the string name of the network, either ethereum or matic
    return:
    -------
    response.json(): queried data in JSON format
    """

    query = """
    {
      sales(
      where: {nft_: {category: "wearable"}, timestamp_gt: """ + str(tscurrent) + """}
        first: 1000
        orderBy: timestamp
        orderDirection: asc
      ) {
        price
        royaltiesCut
        feesCollectorCut
        timestamp
        type
        nft {
          itemType
          metadata {
            wearable {
              bodyShapes
              category
              collection
              rarity
            }
          }
        }

      }
    }

    """
    #print(query)

    response = requests.post('https://api.thegraph.com/subgraphs/name/decentraland/collections-' + str(network) + '-mainnet'
                             '',
                             json={"query":query})

    if response.status_code == 200: # code 200 means no errors 
        return response.json()
    else: # if errors, print the error code for debugging
        raise Exception("Query failed with return code {}".format(response.staus_code))

# %%
#test cell
data = get_data(0, "ethereum")
#display(data)
#data['data']['sales'][999]['timestamp']

# %%
#test cell
len(data['data']['sales'])
data['data']['sales'][999]['timestamp']
# Out:
# '1582437758'

# %%
def get_all_data(tscurrent, network):    
    """This function loops through making API calls to Decentraland collections Subgraph URL
    parameters:
    ------------
    tscurrent: The timestamp to use in the query. The response will be the next 1000 sales after
    this timestamp. 
    network: the string name of the network, either ethereum or matic
    return:
    -------
    df of all the responses concatenated together
    """
    #start df and counter and timer
    dfOG = pd.DataFrame()
    counter = 0
    start = time.time()
    
    #continue looping through the data until a "break" is hit 
    while True:
        #Get the data from above function
        data = get_data(tscurrent, network)
        
        #for Matic, was hitting errors after looping 100 times, this sleep stopped the error 
        time.sleep(1)
        
        #if no data left, break out of loop
        if len(data['data']['sales']) == 0:
            print("break")
            break

        #The commented out code gave future wartning: FutureWarning: The frame.append method is deprecated 
        #and will be removed from pandas in a future version. Use pandas.concat instead.
        #dfOG = dfOG.append(pd.DataFrame.from_dict(data['data']['sales']))
        
        #Used instead of above
        #concat all previous data with the new data
        dfOG = pd.concat([dfOG,pd.DataFrame.from_dict(data['data']['sales'])], ignore_index = True)
        
        #if length is less than 1000, then this represents the last of the sales
        #break from loop
        if len(data['data']['sales']) < 1000:
            print("break")
            break
            
        #update the timestamp to the last sale retrieved, and increment counter
        tscurrent = data['data']['sales'][999]['timestamp']
        counter += 1
        
        #print current timestamp and shape for tracking
        print(tscurrent)
        print(dfOG.shape)
        #print(tscurrent)
    
    #end run time and print time
    end = time.time()
    print(end-start)
    dfOG.head()
    #print( dfOGnewmethod.head())
    
    return dfOG

# %%
#get data for ethereum
dfOG = get_all_data(0, "ethereum")
# Out:
# 1
# (1000, 6)
# 2
# (2000, 6)
# 3
# (3000, 6)
# 4
# (4000, 6)
# 5
# (5000, 6)
# 6
# (6000, 6)
# 7
# (7000, 6)
# 8
# (8000, 6)
# 9
# (9000, 6)
# break
# 20.711683988571167

# %%
#get data for matic/Polygon
dfP = get_all_data(0, "matic")
# Out:
# 1624741533
# (1000, 6)
# 1626738396
# (2000, 6)
# 1629076342
# (3000, 6)
# 1631253852
# (4000, 6)
# 1633221181
# (5000, 6)
# 1634924178
# (6000, 6)
# 1635173197
# (7000, 6)
# 1635607399
# (8000, 6)
# 1636208104
# (9000, 6)
# 1637023942
# (10000, 6)
# 1637590053
# (11000, 6)
# 1638107394
# (12000, 6)
# 1638597951
# (13000, 6)
# 1639096406
# (14000, 6)
# 1639465703
# (15000, 6)
# 1639713398
# (16000, 6)
# 1639969668
# (17000, 6)
# 1640195954
# (18000, 6)
# 1640337769
# (19000, 6)
# 1640504200
# (20000, 6)
# 1640748109
# (21000, 6)
# 1640892310
# (22000, 6)
# 1641051931
# (23000, 6)
# 1641262865
# (24000, 6)
# 1641518097
# (25000, 6)
# 1641599788
# (26000, 6)
# 1641795533
# (27000, 6)
# 1641957858
# (28000, 6)
# 1642118695
# (29000, 6)
# 1642155217
# (30000, 6)
# 1642213220
# (31000, 6)
# 1642267154
# (32000, 6)
# 1642344879
# (33000, 6)
# 1642466502
# (34000, 6)
# 1642609137
# (35000, 6)
# 1642644162
# (36000, 6)
# 1642646488
# (37000, 6)
# 1642649120
# (38000, 6)
# 1642716718
# (39000, 6)
# 1642865333
# (40000, 6)
# 1642989141
# (41000, 6)
# 1643188829
# (42000, 6)
# 1643353364
# (43000, 6)
# 1643482151
# (44000, 6)
# 1643660258
# (45000, 6)
# 1643826189
# (46000, 6)
# 1643869033
# (47000, 6)
# 1644017782
# (48000, 6)
# 1644176666
# (49000, 6)
# 1644370635
# (50000, 6)
# 1644549648
# (51000, 6)
# 1644725129
# (52000, 6)
# 1644868156
# (53000, 6)
# 1644956268
# (54000, 6)
# 1644966021
# (55000, 6)
# 1644982531
# (56000, 6)
# 1645019370
# (57000, 6)
# 1645030891
# (58000, 6)
# 1645041612
# (59000, 6)
# 1645106571
# (60000, 6)
# 1645154676
# (61000, 6)
# 1645218924
# (62000, 6)
# 1645290971
# (63000, 6)
# 1645339007
# (64000, 6)
# 1645426310
# (65000, 6)
# 1645552063
# (66000, 6)
# 1645629392
# (67000, 6)
# 1645673029
# (68000, 6)
# 1645748019
# (69000, 6)
# 1645862065
# (70000, 6)
# 1645941644
# (71000, 6)
# 1645986887
# (72000, 6)
# 1646077792
# (73000, 6)
# 1646175004
# (74000, 6)
# 1646266173
# (75000, 6)
# 1646376023
# (76000, 6)
# 1646511937
# (77000, 6)
# 1646627898
# (78000, 6)
# 1646729085
# (79000, 6)
# 1646845938
# (80000, 6)
# 1646905602
# (81000, 6)
# 1646975571
# (82000, 6)
# 1647103426
# (83000, 6)
# 1647247372
# (84000, 6)
# 1647351469
# (85000, 6)
# 1647476496
# (86000, 6)
# 1647626729
# (87000, 6)
# 1647827637
# (88000, 6)
# 1647999590
# (89000, 6)
# 1648042798
# (90000, 6)
# 1648164097
# (91000, 6)
# 1648204371
# (92000, 6)
# 1648230264
# (93000, 6)
# 1648267899
# (94000, 6)
# 1648377875
# (95000, 6)
# 1648425074
# (96000, 6)
# 1648569890
# (97000, 6)
# 1648768422
# (98000, 6)
# 1648966751
# (99000, 6)
# 1649260986
# (100000, 6)
# 1649553830
# (101000, 6)
# 1649624133
# (102000, 6)
# 1649781927
# (103000, 6)
# 1649973677
# (104000, 6)
# 1650245430
# (105000, 6)
# 1650521610
# (106000, 6)
# 1650817269
# (107000, 6)
# 1650860870
# (108000, 6)
# 1650873574
# (109000, 6)
# 1650885114
# (110000, 6)
# 1650893179
# (111000, 6)
# 1650896791
# (112000, 6)
# 1651109725
# (113000, 6)
# 1651361554
# (114000, 6)
# 1651618374
# (115000, 6)
# 1651940406
# (116000, 6)
# 1652310186
# (117000, 6)
# 1652582008
# (118000, 6)
# 1652883852
# (119000, 6)
# 1653155509
# (120000, 6)
# 1653425631
# (121000, 6)
# 1653664814
# (122000, 6)
# 1653926207
# (123000, 6)
# 1654275245
# (124000, 6)
# 1654655202
# (125000, 6)
# 1655132512
# (126000, 6)
# 1655563074
# (127000, 6)
# 1656003117
# (128000, 6)
# 1656365252
# (129000, 6)
# 1656781948
# (130000, 6)
# 1656983477
# (131000, 6)
# 1657012175
# (132000, 6)
# 1657039287
# (133000, 6)
# 1657373088
# (134000, 6)
# 1657830276
# (135000, 6)
# 1658249989
# (136000, 6)
# 1658782746
# (137000, 6)
# 1659236251
# (138000, 6)
# 1659737310
# (139000, 6)
# 1660268139
# (140000, 6)
# 1660662958
# (141000, 6)
# 1661155098
# (142000, 6)
# 1661642534
# (143000, 6)
# 1662089730
# (144000, 6)
# 1662765932
# (145000, 6)
# 1663261483
# (146000, 6)
# 1663772969
# (147000, 6)
# 1664373735
# (148000, 6)
# 1664819322
# (149000, 6)
# 1665275442
# (150000, 6)
# 1665706318
# (151000, 6)
# 1666380052
# (152000, 6)
# 1666913467
# (153000, 6)
# 1667328810
# (154000, 6)
# 1667738931
# (155000, 6)
# 1668084088
# (156000, 6)
# 1668250537
# (157000, 6)
# 1668379116
# (158000, 6)
# 1668673762
# (159000, 6)
# 1669033131
# (160000, 6)
# 1669471588
# (161000, 6)
# 1669876572
# (162000, 6)
# 1670243153
# (163000, 6)
# 1670851520
# (164000, 6)
# 1671304036
# (165000, 6)
# 1671822581
# (166000, 6)
# 1672419831
# (167000, 6)
# 1673148578
# (168000, 6)
# 1673757150
# (169000, 6)
# 1674333051
# (170000, 6)
# 1674985243
# (171000, 6)
# 1675548752
# (172000, 6)
# 1676079947
# (173000, 6)
# 1676859615
# (174000, 6)
# 1677670837
# (175000, 6)
# 1678325399
# (176000, 6)
# 1679156906
# (177000, 6)
# 1679760661
# (178000, 6)
# 1680037449
# (179000, 6)
# 1680206211
# (180000, 6)
# 1680403139
# (181000, 6)
# 1680828244
# (182000, 6)
# break
# 464.1045575141907

# %%
#take a look at data
dfP
# Out:
#                         price       royaltiesCut      feesCollectorCut  \
# 0       500000000000000000000                  0  12500000000000000000
# 1       100000000000000000000                  0   2500000000000000000
# 2       100000000000000000000                  0   2500000000000000000
# 3       100000000000000000000                  0   2500000000000000000
# 4       100000000000000000000                  0   2500000000000000000
# ...                       ...                ...                   ...
# 182971   15000000000000000000                  0    375000000000000000
# 182972    1000000000000000000                  0     25000000000000000
# 182973    1500000000000000000                  0     37500000000000000
# 182974    3000000000000000000                  0     75000000000000000
# 182975     990000000000000000  24750000000000000                     0
#
#          timestamp   type                                                nft
# 0       1623352144  order  {'itemType': 'wearable_v2', 'metadata': {'wear...
# 1       1623352460  order  {'itemType': 'wearable_v2', 'metadata': {'wear...
# 2       1623352528  order  {'itemType': 'wearable_v2', 'metadata': {'wear...
# 3       1623352602  order  {'itemType': 'wearable_v2', 'metadata': {'wear...
# 4       1623353328  order  {'itemType': 'wearable_v2', 'metadata': {'wear...
# ...            ...    ...                                                ...
# 182971  1681825699   mint  {'itemType': 'wearable_v2', 'metadata': {'wear...
# 182972  1681826803   mint  {'itemType': 'wearable_v2', 'metadata': {'wear...
# 182973  1681826847   mint  {'itemType': 'wearable_v2', 'metadata': {'wear...
# 182974  1681832356   mint  {'itemType': 'wearable_v2', 'metadata': {'wear...
# 182975  1681833320  order  {'itemType': 'wearable_v2', 'metadata': {'wear...
#
# [182976 rows x 6 columns]

# %%
#take a look at data
dfOG
# Out:
#                         price royaltiesCut       feesCollectorCut   timestamp  \
# 0     11111000000000000000000            0  111110000000000000000  1581364178
# 1     25000000000000000000000            0  250000000000000000000  1581364712
# 2       150000000000000000000            0    3750000000000000000  1581960831
# 3       155000000000000000000            0    3875000000000000000  1581960870
# 4       180000000000000000000            0    4500000000000000000  1581963425
# ...                       ...          ...                    ...         ...
# 9277    100000000000000000000            0    2500000000000000000  1674190271
# 9278    149000000000000000000            0    3725000000000000000  1674847043
# 9279     30000000000000000000            0     750000000000000000  1676773607
# 9280     30000000000000000000            0     750000000000000000  1678262027
# 9281    969000000000000000000            0   24225000000000000000  1680459419
#
#        type                                                nft
# 0     order  {'itemType': 'wearable_v1', 'metadata': {'wear...
# 1     order  {'itemType': 'wearable_v1', 'metadata': {'wear...
# 2     order  {'itemType': 'wearable_v1', 'metadata': {'wear...
# 3     order  {'itemType': 'wearable_v1', 'metadata': {'wear...
# 4     order  {'itemType': 'wearable_v1', 'metadata': {'wear...
# ...     ...                                                ...
# 9277  order  {'itemType': 'wearable_v1', 'metadata': {'wear...
# 9278  order  {'itemType': 'wearable_v1', 'metadata': {'wear...
# 9279  order  {'itemType': 'wearable_v1', 'metadata': {'wear...
# 9280  order  {'itemType': 'wearable_v1', 'metadata': {'wear...
# 9281  order  {'itemType': 'wearable_v1', 'metadata': {'wear...
#
# [9282 rows x 6 columns]

# %%
#concat the ethereum and matic df together
df = pd.concat([dfOG,dfP], ignore_index = True)
df
# Out:
#                           price       royaltiesCut       feesCollectorCut  \
# 0       11111000000000000000000                  0  111110000000000000000
# 1       25000000000000000000000                  0  250000000000000000000
# 2         150000000000000000000                  0    3750000000000000000
# 3         155000000000000000000                  0    3875000000000000000
# 4         180000000000000000000                  0    4500000000000000000
# ...                         ...                ...                    ...
# 192253     15000000000000000000                  0     375000000000000000
# 192254      1000000000000000000                  0      25000000000000000
# 192255      1500000000000000000                  0      37500000000000000
# 192256      3000000000000000000                  0      75000000000000000
# 192257       990000000000000000  24750000000000000                      0
#
#          timestamp   type                                                nft
# 0       1581364178  order  {'itemType': 'wearable_v1', 'metadata': {'wear...
# 1       1581364712  order  {'itemType': 'wearable_v1', 'metadata': {'wear...
# 2       1581960831  order  {'itemType': 'wearable_v1', 'metadata': {'wear...
# 3       1581960870  order  {'itemType': 'wearable_v1', 'metadata': {'wear...
# 4       1581963425  order  {'itemType': 'wearable_v1', 'metadata': {'wear...
# ...            ...    ...                                                ...
# 192253  1681825699   mint  {'itemType': 'wearable_v2', 'metadata': {'wear...
# 192254  1681826803   mint  {'itemType': 'wearable_v2', 'metadata': {'wear...
# 192255  1681826847   mint  {'itemType': 'wearable_v2', 'metadata': {'wear...
# 192256  1681832356   mint  {'itemType': 'wearable_v2', 'metadata': {'wear...
# 192257  1681833320  order  {'itemType': 'wearable_v2', 'metadata': {'wear...
#
# [192258 rows x 6 columns]

# %%
#a few columns have multiple items in it
#split them a part and concat together
df = pd.concat([df.drop(['nft'], axis = 1), df['nft'].apply(pd.Series)],axis = 1)
df = pd.concat([df.drop(['metadata'], axis = 1), df['metadata'].apply(pd.Series)],axis = 1)           
df = pd.concat([df.drop(['wearable'], axis = 1), df['wearable'].apply(pd.Series)],axis = 1)
df
# Out:
#                           price       royaltiesCut       feesCollectorCut  \
# 0       11111000000000000000000                  0  111110000000000000000
# 1       25000000000000000000000                  0  250000000000000000000
# 2         150000000000000000000                  0    3750000000000000000
# 3         155000000000000000000                  0    3875000000000000000
# 4         180000000000000000000                  0    4500000000000000000
# ...                         ...                ...                    ...
# 192253     15000000000000000000                  0     375000000000000000
# 192254      1000000000000000000                  0      25000000000000000
# 192255      1500000000000000000                  0      37500000000000000
# 192256      3000000000000000000                  0      75000000000000000
# 192257       990000000000000000  24750000000000000                      0
#
#          timestamp   type     itemType              bodyShapes    category  \
# 0       1581364178  order  wearable_v1              [BaseMale]  upper_body
# 1       1581364712  order  wearable_v1  [BaseMale, BaseFemale]        mask
# 2       1581960831  order  wearable_v1  [BaseMale, BaseFemale]         hat
# 3       1581960870  order  wearable_v1  [BaseMale, BaseFemale]      helmet
# 4       1581963425  order  wearable_v1  [BaseMale, BaseFemale]         hat
# ...            ...    ...          ...                     ...         ...
# 192253  1681825699   mint  wearable_v2            [BaseFemale]  upper_body
# 192254  1681826803   mint  wearable_v2  [BaseMale, BaseFemale]  upper_body
# 192255  1681826847   mint  wearable_v2  [BaseMale, BaseFemale]     eyewear
# 192256  1681832356   mint  wearable_v2  [BaseMale, BaseFemale]       mouth
# 192257  1681833320  order  wearable_v2  [BaseMale, BaseFemale]  lower_body
#
#                                         collection     rarity
# 0       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       epic
# 1       0xc04528c14c8ffd84c7c1fb6719b4a89853035cdd  legendary
# 2       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare
# 3       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare
# 4       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare
# ...                                            ...        ...
# 192253  0x9376f00e31c46a05dcad41ef7308a25ff1ccffb0  legendary
# 192254  0x0a04cca75b74c69ac5ad2e219d1b9c180d8fc746     common
# 192255  0x8cdf396bc0244544af18e30bf4f42db50d75b030       epic
# 192256  0x563e2081b3cd716ed76fc0993b7e49939cb342a5       epic
# 192257  0xb48c49837467698962753e512670e3d5d874b627  legendary
#
# [192258 rows x 10 columns]

# %%
#see some df info
df.describe()
# Out:
#                       price royaltiesCut feesCollectorCut   timestamp    type  \
# count                192258       192258           192258      192258  192258
# unique                 1154          690              786      182551       3
# top     1000000000000000000            0                0  1668355148    mint
# freq                  26691       148883            43375          22  128909
#
#            itemType              bodyShapes    category  \
# count        192258                  192258      192258
# unique            3                       4          16
# top     wearable_v2  [BaseMale, BaseFemale]  upper_body
# freq         182082                  164068       59893
#
#                                         collection  rarity
# count                                       192258  192258
# unique                                        3322       7
# top     0xca3f06d124850ea57db0d6fcc4295b2e03a2bbe3    epic
# freq                                          7832   54053

# %%
#Change all prices to float and get it to correct units
#the prices are recorded with 18 extra 0s
df['price'] = df['price'].astype(np.float64)
df['price'] = df['price']/10**18
df['royaltiesCut'] = df['royaltiesCut'].astype(np.float64)
df['royaltiesCut'] = df['royaltiesCut']/10**18
df['feesCollectorCut'] = df['feesCollectorCut'].astype(np.float64)
df['feesCollectorCut'] = df['feesCollectorCut']/10**18

#Change to correct types
df['timestamp'].astype(int)
df['Date'] = pd.to_datetime(df['timestamp'],unit='s').dt.date
print(df.shape)
df.head()
# Out:
# (192258, 11)
#      price  royaltiesCut  feesCollectorCut   timestamp   type     itemType  \
# 0  11111.0           0.0           111.110  1581364178  order  wearable_v1
# 1  25000.0           0.0           250.000  1581364712  order  wearable_v1
# 2    150.0           0.0             3.750  1581960831  order  wearable_v1
# 3    155.0           0.0             3.875  1581960870  order  wearable_v1
# 4    180.0           0.0             4.500  1581963425  order  wearable_v1
#
#                bodyShapes    category  \
# 0              [BaseMale]  upper_body
# 1  [BaseMale, BaseFemale]        mask
# 2  [BaseMale, BaseFemale]         hat
# 3  [BaseMale, BaseFemale]      helmet
# 4  [BaseMale, BaseFemale]         hat
#
#                                    collection     rarity        Date
# 0  0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       epic  2020-02-10
# 1  0xc04528c14c8ffd84c7c1fb6719b4a89853035cdd  legendary  2020-02-10
# 2  0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare  2020-02-17
# 3  0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare  2020-02-17
# 4  0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare  2020-02-17

# %%
#check the counts of same variables
print(df['itemType'].value_counts())
print(df['type'].value_counts())
# Out:
# wearable_v2          182082
# wearable_v1            9282
# smart_wearable_v1       894
# Name: itemType, dtype: int64
# mint     128909
# order     57107
# bid        6242
# Name: type, dtype: int64

# %%
#merge royaltiescut and feescollectors cut to one column
mask = df['feesCollectorCut'] == 0
df['Fee'] = np.where(mask, df['royaltiesCut'], df['feesCollectorCut'])
df
# Out:
#            price  royaltiesCut  feesCollectorCut   timestamp   type  \
# 0       11111.00       0.00000          111.1100  1581364178  order
# 1       25000.00       0.00000          250.0000  1581364712  order
# 2         150.00       0.00000            3.7500  1581960831  order
# 3         155.00       0.00000            3.8750  1581960870  order
# 4         180.00       0.00000            4.5000  1581963425  order
# ...          ...           ...               ...         ...    ...
# 192253     15.00       0.00000            0.3750  1681825699   mint
# 192254      1.00       0.00000            0.0250  1681826803   mint
# 192255      1.50       0.00000            0.0375  1681826847   mint
# 192256      3.00       0.00000            0.0750  1681832356   mint
# 192257      0.99       0.02475            0.0000  1681833320  order
#
#            itemType              bodyShapes    category  \
# 0       wearable_v1              [BaseMale]  upper_body
# 1       wearable_v1  [BaseMale, BaseFemale]        mask
# 2       wearable_v1  [BaseMale, BaseFemale]         hat
# 3       wearable_v1  [BaseMale, BaseFemale]      helmet
# 4       wearable_v1  [BaseMale, BaseFemale]         hat
# ...             ...                     ...         ...
# 192253  wearable_v2            [BaseFemale]  upper_body
# 192254  wearable_v2  [BaseMale, BaseFemale]  upper_body
# 192255  wearable_v2  [BaseMale, BaseFemale]     eyewear
# 192256  wearable_v2  [BaseMale, BaseFemale]       mouth
# 192257  wearable_v2  [BaseMale, BaseFemale]  lower_body
#
#                                         collection     rarity        Date  \
# 0       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       epic  2020-02-10
# 1       0xc04528c14c8ffd84c7c1fb6719b4a89853035cdd  legendary  2020-02-10
# 2       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare  2020-02-17
# 3       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare  2020-02-17
# 4       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare  2020-02-17
# ...                                            ...        ...         ...
# 192253  0x9376f00e31c46a05dcad41ef7308a25ff1ccffb0  legendary  2023-04-18
# 192254  0x0a04cca75b74c69ac5ad2e219d1b9c180d8fc746     common  2023-04-18
# 192255  0x8cdf396bc0244544af18e30bf4f42db50d75b030       epic  2023-04-18
# 192256  0x563e2081b3cd716ed76fc0993b7e49939cb342a5       epic  2023-04-18
# 192257  0xb48c49837467698962753e512670e3d5d874b627  legendary  2023-04-18
#
#               Fee
# 0       111.11000
# 1       250.00000
# 2         3.75000
# 3         3.87500
# 4         4.50000
# ...           ...
# 192253    0.37500
# 192254    0.02500
# 192255    0.03750
# 192256    0.07500
# 192257    0.02475
#
# [192258 rows x 12 columns]

# %%
#wearable_v1 is Ethereum, the other two are Polygon
#make column to say which network
mask1 = df['itemType'] == "wearable_v1"
df['Network'] = np.where(mask1, "Ethereum", "Polygon")
df
# Out:
#            price  royaltiesCut  feesCollectorCut   timestamp   type  \
# 0       11111.00       0.00000          111.1100  1581364178  order
# 1       25000.00       0.00000          250.0000  1581364712  order
# 2         150.00       0.00000            3.7500  1581960831  order
# 3         155.00       0.00000            3.8750  1581960870  order
# 4         180.00       0.00000            4.5000  1581963425  order
# ...          ...           ...               ...         ...    ...
# 192253     15.00       0.00000            0.3750  1681825699   mint
# 192254      1.00       0.00000            0.0250  1681826803   mint
# 192255      1.50       0.00000            0.0375  1681826847   mint
# 192256      3.00       0.00000            0.0750  1681832356   mint
# 192257      0.99       0.02475            0.0000  1681833320  order
#
#            itemType              bodyShapes    category  \
# 0       wearable_v1              [BaseMale]  upper_body
# 1       wearable_v1  [BaseMale, BaseFemale]        mask
# 2       wearable_v1  [BaseMale, BaseFemale]         hat
# 3       wearable_v1  [BaseMale, BaseFemale]      helmet
# 4       wearable_v1  [BaseMale, BaseFemale]         hat
# ...             ...                     ...         ...
# 192253  wearable_v2            [BaseFemale]  upper_body
# 192254  wearable_v2  [BaseMale, BaseFemale]  upper_body
# 192255  wearable_v2  [BaseMale, BaseFemale]     eyewear
# 192256  wearable_v2  [BaseMale, BaseFemale]       mouth
# 192257  wearable_v2  [BaseMale, BaseFemale]  lower_body
#
#                                         collection     rarity        Date  \
# 0       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       epic  2020-02-10
# 1       0xc04528c14c8ffd84c7c1fb6719b4a89853035cdd  legendary  2020-02-10
# 2       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare  2020-02-17
# 3       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare  2020-02-17
# 4       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare  2020-02-17
# ...                                            ...        ...         ...
# 192253  0x9376f00e31c46a05dcad41ef7308a25ff1ccffb0  legendary  2023-04-18
# 192254  0x0a04cca75b74c69ac5ad2e219d1b9c180d8fc746     common  2023-04-18
# 192255  0x8cdf396bc0244544af18e30bf4f42db50d75b030       epic  2023-04-18
# 192256  0x563e2081b3cd716ed76fc0993b7e49939cb342a5       epic  2023-04-18
# 192257  0xb48c49837467698962753e512670e3d5d874b627  legendary  2023-04-18
#
#               Fee   Network
# 0       111.11000  Ethereum
# 1       250.00000  Ethereum
# 2         3.75000  Ethereum
# 3         3.87500  Ethereum
# 4         4.50000  Ethereum
# ...           ...       ...
# 192253    0.37500   Polygon
# 192254    0.02500   Polygon
# 192255    0.03750   Polygon
# 192256    0.07500   Polygon
# 192257    0.02475   Polygon
#
# [192258 rows x 13 columns]

# %%
def Body(row):
    """This function returns a single letter for bodyshape.
    ------------
    row: This function will be used in a df.apply and each row of the df will sent through
    this function
    return:
    -------
    M for male, F for female, U for Unisex
    """
    if row['bodyShapes'] == ['BaseMale']:
        return 'M'
    elif row['bodyShapes'] == ['BaseFemale']:
        return 'F'
    elif row['bodyShapes'] == ['BaseMale','BaseFemale']:
        return 'U'
    elif row['bodyShapes'] == ['BaseFemale','BaseMale']:
        return 'U'

# %%
#apply above function to df
df['BodyShape'] = df.apply(Body, axis=1)
df
# Out:
#            price  royaltiesCut  feesCollectorCut   timestamp   type  \
# 0       11111.00       0.00000          111.1100  1581364178  order
# 1       25000.00       0.00000          250.0000  1581364712  order
# 2         150.00       0.00000            3.7500  1581960831  order
# 3         155.00       0.00000            3.8750  1581960870  order
# 4         180.00       0.00000            4.5000  1581963425  order
# ...          ...           ...               ...         ...    ...
# 192253     15.00       0.00000            0.3750  1681825699   mint
# 192254      1.00       0.00000            0.0250  1681826803   mint
# 192255      1.50       0.00000            0.0375  1681826847   mint
# 192256      3.00       0.00000            0.0750  1681832356   mint
# 192257      0.99       0.02475            0.0000  1681833320  order
#
#            itemType              bodyShapes    category  \
# 0       wearable_v1              [BaseMale]  upper_body
# 1       wearable_v1  [BaseMale, BaseFemale]        mask
# 2       wearable_v1  [BaseMale, BaseFemale]         hat
# 3       wearable_v1  [BaseMale, BaseFemale]      helmet
# 4       wearable_v1  [BaseMale, BaseFemale]         hat
# ...             ...                     ...         ...
# 192253  wearable_v2            [BaseFemale]  upper_body
# 192254  wearable_v2  [BaseMale, BaseFemale]  upper_body
# 192255  wearable_v2  [BaseMale, BaseFemale]     eyewear
# 192256  wearable_v2  [BaseMale, BaseFemale]       mouth
# 192257  wearable_v2  [BaseMale, BaseFemale]  lower_body
#
#                                         collection     rarity        Date  \
# 0       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       epic  2020-02-10
# 1       0xc04528c14c8ffd84c7c1fb6719b4a89853035cdd  legendary  2020-02-10
# 2       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare  2020-02-17
# 3       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare  2020-02-17
# 4       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare  2020-02-17
# ...                                            ...        ...         ...
# 192253  0x9376f00e31c46a05dcad41ef7308a25ff1ccffb0  legendary  2023-04-18
# 192254  0x0a04cca75b74c69ac5ad2e219d1b9c180d8fc746     common  2023-04-18
# 192255  0x8cdf396bc0244544af18e30bf4f42db50d75b030       epic  2023-04-18
# 192256  0x563e2081b3cd716ed76fc0993b7e49939cb342a5       epic  2023-04-18
# 192257  0xb48c49837467698962753e512670e3d5d874b627  legendary  2023-04-18
#
#               Fee   Network BodyShape
# 0       111.11000  Ethereum         M
# 1       250.00000  Ethereum         U
# 2         3.75000  Ethereum         U
# 3         3.87500  Ethereum         U
# 4         4.50000  Ethereum         U
# ...           ...       ...       ...
# 192253    0.37500   Polygon         F
# 192254    0.02500   Polygon         U
# 192255    0.03750   Polygon         U
# 192256    0.07500   Polygon         U
# 192257    0.02475   Polygon         U
#
# [192258 rows x 14 columns]

# %%
#change type
df["Date"] = df["Date"].astype('datetime64[ns]')

# %%
df.dtypes
# Out:
# price                      float64
# royaltiesCut               float64
# feesCollectorCut           float64
# timestamp                   object
# type                        object
# itemType                    object
# bodyShapes                  object
# category                    object
# collection                  object
# rarity                      object
# Date                datetime64[ns]
# Fee                        float64
# Network                     object
# BodyShape                   object
# dtype: object

# %%
#Get the first date of a sale from the data
firstdate = df.loc[0,'Date']
lastdate = df.loc[len(df['Date'])-1,'Date']

#Get the quantity of days from first sale to today
#This will be used in upcoming cells to get daily historical coin prices
days = datetime.now() - firstdate
days.days
# Out:
# 1163

# %%
#api url for MANA historical prices
url = 'https://api.coingecko.com/api/v3/coins/decentraland/market_chart?vs_currency=usd&days=' + str(days.days+1)

#make API call to coingecko
response = requests.get(url)
#response.json()['prices']

#set json to df and set columns to correct type
manadf = pd.DataFrame(response.json()['prices'], columns = ['timestamp','MANA price (USD)'])
manadf['Date'] = pd.to_datetime(manadf['timestamp'],unit='ms').dt.date
manadf["Date"] = manadf["Date"].astype('datetime64[ns]')

#drop last row because both same day
manadf.drop(manadf.tail(1).index,inplace=True)

#drop timestamp, not needed
manadf = manadf.drop(['timestamp'], axis=1)
manadf
# Out:
#       MANA price (USD)       Date
# 0             0.064333 2020-02-10
# 1             0.060102 2020-02-11
# 2             0.064091 2020-02-12
# 3             0.061613 2020-02-13
# 4             0.060294 2020-02-14
# ...                ...        ...
# 1159          0.618217 2023-04-14
# 1160          0.640651 2023-04-15
# 1161          0.640651 2023-04-16
# 1162          0.644682 2023-04-17
# 1163          0.691581 2023-04-18
#
# [1164 rows x 2 columns]

# %%
#api url for ETH historical prices
url = 'https://api.coingecko.com/api/v3/coins/ethereum/market_chart?vs_currency=usd&days=' + str(days.days+1)

#make API call to coingecko
response = requests.get(url)

#set json to df and set columns to correct type
ethdf = pd.DataFrame(response.json()['prices'], columns = ['timestamp','ETH price (USD)'])
ethdf['Date'] = pd.to_datetime(ethdf['timestamp'],unit='ms').dt.date
ethdf["Date"] = ethdf["Date"].astype('datetime64[ns]')

#drop last row because both same day
ethdf.drop(ethdf.tail(1).index,inplace=True)

#drop timestamp, not needed
ethdf = ethdf.drop(['timestamp'], axis=1)
ethdf
# Out:
#       ETH price (USD)       Date
# 0          228.292261 2020-02-10
# 1          224.146997 2020-02-11
# 2          236.785349 2020-02-12
# 3          264.032768 2020-02-13
# 4          267.670445 2020-02-14
# ...               ...        ...
# 1159      2012.785415 2023-04-14
# 1160      2102.946188 2023-04-15
# 1161      2093.166331 2023-04-16
# 1162      2118.598789 2023-04-17
# 1163      2077.535665 2023-04-18
#
# [1164 rows x 2 columns]

# %%
#Merge main df with MANA and ETH historical prices
df = pd.merge(df,manadf,on='Date', how='left')

# %%
df = pd.merge(df,ethdf,on='Date', how='left')
df
# Out:
#            price  royaltiesCut  feesCollectorCut   timestamp   type  \
# 0       11111.00       0.00000          111.1100  1581364178  order
# 1       25000.00       0.00000          250.0000  1581364712  order
# 2         150.00       0.00000            3.7500  1581960831  order
# 3         155.00       0.00000            3.8750  1581960870  order
# 4         180.00       0.00000            4.5000  1581963425  order
# ...          ...           ...               ...         ...    ...
# 192253     15.00       0.00000            0.3750  1681825699   mint
# 192254      1.00       0.00000            0.0250  1681826803   mint
# 192255      1.50       0.00000            0.0375  1681826847   mint
# 192256      3.00       0.00000            0.0750  1681832356   mint
# 192257      0.99       0.02475            0.0000  1681833320  order
#
#            itemType              bodyShapes    category  \
# 0       wearable_v1              [BaseMale]  upper_body
# 1       wearable_v1  [BaseMale, BaseFemale]        mask
# 2       wearable_v1  [BaseMale, BaseFemale]         hat
# 3       wearable_v1  [BaseMale, BaseFemale]      helmet
# 4       wearable_v1  [BaseMale, BaseFemale]         hat
# ...             ...                     ...         ...
# 192253  wearable_v2            [BaseFemale]  upper_body
# 192254  wearable_v2  [BaseMale, BaseFemale]  upper_body
# 192255  wearable_v2  [BaseMale, BaseFemale]     eyewear
# 192256  wearable_v2  [BaseMale, BaseFemale]       mouth
# 192257  wearable_v2  [BaseMale, BaseFemale]  lower_body
#
#                                         collection     rarity       Date  \
# 0       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       epic 2020-02-10
# 1       0xc04528c14c8ffd84c7c1fb6719b4a89853035cdd  legendary 2020-02-10
# 2       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare 2020-02-17
# 3       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare 2020-02-17
# 4       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare 2020-02-17
# ...                                            ...        ...        ...
# 192253  0x9376f00e31c46a05dcad41ef7308a25ff1ccffb0  legendary 2023-04-18
# 192254  0x0a04cca75b74c69ac5ad2e219d1b9c180d8fc746     common 2023-04-18
# 192255  0x8cdf396bc0244544af18e30bf4f42db50d75b030       epic 2023-04-18
# 192256  0x563e2081b3cd716ed76fc0993b7e49939cb342a5       epic 2023-04-18
# 192257  0xb48c49837467698962753e512670e3d5d874b627  legendary 2023-04-18
#
#               Fee   Network BodyShape  MANA price (USD)  ETH price (USD)
# 0       111.11000  Ethereum         M          0.064333       228.292261
# 1       250.00000  Ethereum         U          0.064333       228.292261
# 2         3.75000  Ethereum         U          0.057185       262.156244
# 3         3.87500  Ethereum         U          0.057185       262.156244
# 4         4.50000  Ethereum         U          0.057185       262.156244
# ...           ...       ...       ...               ...              ...
# 192253    0.37500   Polygon         F          0.691581      2077.535665
# 192254    0.02500   Polygon         U          0.691581      2077.535665
# 192255    0.03750   Polygon         U          0.691581      2077.535665
# 192256    0.07500   Polygon         U          0.691581      2077.535665
# 192257    0.02475   Polygon         U          0.691581      2077.535665
#
# [192258 rows x 16 columns]

# %%
#calculate fee percentages
df['Fee Percentage'] = df['Fee']/df['price']
df
# Out:
#            price  royaltiesCut  feesCollectorCut   timestamp   type  \
# 0       11111.00       0.00000          111.1100  1581364178  order
# 1       25000.00       0.00000          250.0000  1581364712  order
# 2         150.00       0.00000            3.7500  1581960831  order
# 3         155.00       0.00000            3.8750  1581960870  order
# 4         180.00       0.00000            4.5000  1581963425  order
# ...          ...           ...               ...         ...    ...
# 192253     15.00       0.00000            0.3750  1681825699   mint
# 192254      1.00       0.00000            0.0250  1681826803   mint
# 192255      1.50       0.00000            0.0375  1681826847   mint
# 192256      3.00       0.00000            0.0750  1681832356   mint
# 192257      0.99       0.02475            0.0000  1681833320  order
#
#            itemType              bodyShapes    category  \
# 0       wearable_v1              [BaseMale]  upper_body
# 1       wearable_v1  [BaseMale, BaseFemale]        mask
# 2       wearable_v1  [BaseMale, BaseFemale]         hat
# 3       wearable_v1  [BaseMale, BaseFemale]      helmet
# 4       wearable_v1  [BaseMale, BaseFemale]         hat
# ...             ...                     ...         ...
# 192253  wearable_v2            [BaseFemale]  upper_body
# 192254  wearable_v2  [BaseMale, BaseFemale]  upper_body
# 192255  wearable_v2  [BaseMale, BaseFemale]     eyewear
# 192256  wearable_v2  [BaseMale, BaseFemale]       mouth
# 192257  wearable_v2  [BaseMale, BaseFemale]  lower_body
#
#                                         collection     rarity       Date  \
# 0       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       epic 2020-02-10
# 1       0xc04528c14c8ffd84c7c1fb6719b4a89853035cdd  legendary 2020-02-10
# 2       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare 2020-02-17
# 3       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare 2020-02-17
# 4       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare 2020-02-17
# ...                                            ...        ...        ...
# 192253  0x9376f00e31c46a05dcad41ef7308a25ff1ccffb0  legendary 2023-04-18
# 192254  0x0a04cca75b74c69ac5ad2e219d1b9c180d8fc746     common 2023-04-18
# 192255  0x8cdf396bc0244544af18e30bf4f42db50d75b030       epic 2023-04-18
# 192256  0x563e2081b3cd716ed76fc0993b7e49939cb342a5       epic 2023-04-18
# 192257  0xb48c49837467698962753e512670e3d5d874b627  legendary 2023-04-18
#
#               Fee   Network BodyShape  MANA price (USD)  ETH price (USD)  \
# 0       111.11000  Ethereum         M          0.064333       228.292261
# 1       250.00000  Ethereum         U          0.064333       228.292261
# 2         3.75000  Ethereum         U          0.057185       262.156244
# 3         3.87500  Ethereum         U          0.057185       262.156244
# 4         4.50000  Ethereum         U          0.057185       262.156244
# ...           ...       ...       ...               ...              ...
# 192253    0.37500   Polygon         F          0.691581      2077.535665
# 192254    0.02500   Polygon         U          0.691581      2077.535665
# 192255    0.03750   Polygon         U          0.691581      2077.535665
# 192256    0.07500   Polygon         U          0.691581      2077.535665
# 192257    0.02475   Polygon         U          0.691581      2077.535665
#
#         Fee Percentage
# 0                0.010
# 1                0.010
# 2                0.025
# 3                0.025
# 4                0.025
# ...                ...
# 192253           0.025
# 192254           0.025
# 192255           0.025
# 192256           0.025
# 192257           0.025
#
# [192258 rows x 17 columns]

# %%
#check value counts for fee percentages
#almost all are the same, so not needed
print(df['Fee Percentage'].value_counts())
# Out:
# 0.025    139087
# 0.025     51800
# 0.025      1334
# 0.025        35
# 0.010         1
# 0.010         1
# Name: Fee Percentage, dtype: int64

# %%
#Rename columns to clarify
df.rename(columns = {'price':'sale price (MANA)'}, inplace = True)

#Get sale price in USD
df['sale price (USD)'] = df['sale price (MANA)']*df['MANA price (USD)']
df
# Out:
#         sale price (MANA)  royaltiesCut  feesCollectorCut   timestamp   type  \
# 0                11111.00       0.00000          111.1100  1581364178  order
# 1                25000.00       0.00000          250.0000  1581364712  order
# 2                  150.00       0.00000            3.7500  1581960831  order
# 3                  155.00       0.00000            3.8750  1581960870  order
# 4                  180.00       0.00000            4.5000  1581963425  order
# ...                   ...           ...               ...         ...    ...
# 192253              15.00       0.00000            0.3750  1681825699   mint
# 192254               1.00       0.00000            0.0250  1681826803   mint
# 192255               1.50       0.00000            0.0375  1681826847   mint
# 192256               3.00       0.00000            0.0750  1681832356   mint
# 192257               0.99       0.02475            0.0000  1681833320  order
#
#            itemType              bodyShapes    category  \
# 0       wearable_v1              [BaseMale]  upper_body
# 1       wearable_v1  [BaseMale, BaseFemale]        mask
# 2       wearable_v1  [BaseMale, BaseFemale]         hat
# 3       wearable_v1  [BaseMale, BaseFemale]      helmet
# 4       wearable_v1  [BaseMale, BaseFemale]         hat
# ...             ...                     ...         ...
# 192253  wearable_v2            [BaseFemale]  upper_body
# 192254  wearable_v2  [BaseMale, BaseFemale]  upper_body
# 192255  wearable_v2  [BaseMale, BaseFemale]     eyewear
# 192256  wearable_v2  [BaseMale, BaseFemale]       mouth
# 192257  wearable_v2  [BaseMale, BaseFemale]  lower_body
#
#                                         collection     rarity       Date  \
# 0       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       epic 2020-02-10
# 1       0xc04528c14c8ffd84c7c1fb6719b4a89853035cdd  legendary 2020-02-10
# 2       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare 2020-02-17
# 3       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare 2020-02-17
# 4       0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2       rare 2020-02-17
# ...                                            ...        ...        ...
# 192253  0x9376f00e31c46a05dcad41ef7308a25ff1ccffb0  legendary 2023-04-18
# 192254  0x0a04cca75b74c69ac5ad2e219d1b9c180d8fc746     common 2023-04-18
# 192255  0x8cdf396bc0244544af18e30bf4f42db50d75b030       epic 2023-04-18
# 192256  0x563e2081b3cd716ed76fc0993b7e49939cb342a5       epic 2023-04-18
# 192257  0xb48c49837467698962753e512670e3d5d874b627  legendary 2023-04-18
#
#               Fee   Network BodyShape  MANA price (USD)  ETH price (USD)  \
# 0       111.11000  Ethereum         M          0.064333       228.292261
# 1       250.00000  Ethereum         U          0.064333       228.292261
# 2         3.75000  Ethereum         U          0.057185       262.156244
# 3         3.87500  Ethereum         U          0.057185       262.156244
# 4         4.50000  Ethereum         U          0.057185       262.156244
# ...           ...       ...       ...               ...              ...
# 192253    0.37500   Polygon         F          0.691581      2077.535665
# 192254    0.02500   Polygon         U          0.691581      2077.535665
# 192255    0.03750   Polygon         U          0.691581      2077.535665
# 192256    0.07500   Polygon         U          0.691581      2077.535665
# 192257    0.02475   Polygon         U          0.691581      2077.535665
#
#         Fee Percentage  sale price (USD)
# 0                0.010        714.798988
# 1                0.010       1608.313807
# 2                0.025          8.577801
# 3                0.025          8.863727
# 4                0.025         10.293361
# ...                ...               ...
# 192253           0.025         10.373708
# 192254           0.025          0.691581
# 192255           0.025          1.037371
# 192256           0.025          2.074742
# 192257           0.025          0.684665
#
# [192258 rows x 18 columns]

# %%
#check correlations between variables
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\Bamar\AppData\Local\Temp\ipykernel_23784\3784545759.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <style type="text/css">
# #T_51a5c_row0_col0, #T_51a5c_row1_col1, #T_51a5c_row2_col2, #T_51a5c_row3_col3, #T_51a5c_row4_col4, #T_51a5c_row5_col5, #T_51a5c_row6_col6, #T_51a5c_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_51a5c_row0_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_51a5c_row0_col2 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_51a5c_row0_col3, #T_51a5c_row3_col0 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_51a5c_row0_col4, #T_51a5c_row0_col5, #T_51a5c_row0_col6, #T_51a5c_row2_col4, #T_51a5c_row2_col5, #T_51a5c_row3_col4, #T_51a5c_row3_col5, #T_51a5c_row4_col1, #T_51a5c_row4_col2, #T_51a5c_row4_col3, #T_51a5c_row5_col1, #T_51a5c_row5_col2, #T_51a5c_row5_col3, #T_51a5c_row6_col0, #T_51a5c_row6_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_51a5c_row0_col7 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_51a5c_row1_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_51a5c_row1_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_51a5c_row1_col3, #T_51a5c_row7_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_51a5c_row1_col4, #T_51a5c_row4_col0 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_51a5c_row1_col5 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_51a5c_row1_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_51a5c_row1_col7 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_51a5c_row2_col0 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_51a5c_row2_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_51a5c_row2_col3, #T_51a5c_row3_col2 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_51a5c_row2_col6, #T_51a5c_row3_col6, #T_51a5c_row5_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_51a5c_row2_col7 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_51a5c_row3_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_51a5c_row3_col7 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_51a5c_row4_col5, #T_51a5c_row5_col4 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_51a5c_row4_col6, #T_51a5c_row5_col6, #T_51a5c_row7_col5 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_51a5c_row4_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_51a5c_row5_col0 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_51a5c_row6_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_51a5c_row6_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_51a5c_row6_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_51a5c_row6_col4 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_51a5c_row6_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_51a5c_row7_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_51a5c_row7_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_51a5c_row7_col3 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_51a5c_row7_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_51a5c_row7_col6 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_51a5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51a5c_level0_col0" class="col_heading level0 col0" >sale price (MANA)</th>
#       <th id="T_51a5c_level0_col1" class="col_heading level0 col1" >royaltiesCut</th>
#       <th id="T_51a5c_level0_col2" class="col_heading level0 col2" >feesCollectorCut</th>
#       <th id="T_51a5c_level0_col3" class="col_heading level0 col3" >Fee</th>
#       <th id="T_51a5c_level0_col4" class="col_heading level0 col4" >MANA price (USD)</th>
#       <th id="T_51a5c_level0_col5" class="col_heading level0 col5" >ETH price (USD)</th>
#       <th id="T_51a5c_level0_col6" class="col_heading level0 col6" >Fee Percentage</th>
#       <th id="T_51a5c_level0_col7" class="col_heading level0 col7" >sale price (USD)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51a5c_level0_row0" class="row_heading level0 row0" >sale price (MANA)</th>
#       <td id="T_51a5c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_51a5c_row0_col1" class="data row0 col1" >0.166592</td>
#       <td id="T_51a5c_row0_col2" class="data row0 col2" >0.977453</td>
#       <td id="T_51a5c_row0_col3" class="data row0 col3" >0.992059</td>
#       <td id="T_51a5c_row0_col4" class="data row0 col4" >-0.101561</td>
#       <td id="T_51a5c_row0_col5" class="data row0 col5" >-0.105718</td>
#       <td id="T_51a5c_row0_col6" class="data row0 col6" >-0.196056</td>
#       <td id="T_51a5c_row0_col7" class="data row0 col7" >0.386172</td>
#     </tr>
#     <tr>
#       <th id="T_51a5c_level0_row1" class="row_heading level0 row1" >royaltiesCut</th>
#       <td id="T_51a5c_row1_col0" class="data row1 col0" >0.166592</td>
#       <td id="T_51a5c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_51a5c_row1_col2" class="data row1 col2" >-0.003094</td>
#       <td id="T_51a5c_row1_col3" class="data row1 col3" >0.169785</td>
#       <td id="T_51a5c_row1_col4" class="data row1 col4" >-0.014715</td>
#       <td id="T_51a5c_row1_col5" class="data row1 col5" >-0.013875</td>
#       <td id="T_51a5c_row1_col6" class="data row1 col6" >0.000104</td>
#       <td id="T_51a5c_row1_col7" class="data row1 col7" >0.236465</td>
#     </tr>
#     <tr>
#       <th id="T_51a5c_level0_row2" class="row_heading level0 row2" >feesCollectorCut</th>
#       <td id="T_51a5c_row2_col0" class="data row2 col0" >0.977453</td>
#       <td id="T_51a5c_row2_col1" class="data row2 col1" >-0.003094</td>
#       <td id="T_51a5c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_51a5c_row2_col3" class="data row2 col3" >0.984951</td>
#       <td id="T_51a5c_row2_col4" class="data row2 col4" >-0.101825</td>
#       <td id="T_51a5c_row2_col5" class="data row2 col5" >-0.106019</td>
#       <td id="T_51a5c_row2_col6" class="data row2 col6" >-0.080919</td>
#       <td id="T_51a5c_row2_col7" class="data row2 col7" >0.355206</td>
#     </tr>
#     <tr>
#       <th id="T_51a5c_level0_row3" class="row_heading level0 row3" >Fee</th>
#       <td id="T_51a5c_row3_col0" class="data row3 col0" >0.992059</td>
#       <td id="T_51a5c_row3_col1" class="data row3 col1" >0.169785</td>
#       <td id="T_51a5c_row3_col2" class="data row3 col2" >0.984951</td>
#       <td id="T_51a5c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_51a5c_row3_col4" class="data row3 col4" >-0.102890</td>
#       <td id="T_51a5c_row3_col5" class="data row3 col5" >-0.106879</td>
#       <td id="T_51a5c_row3_col6" class="data row3 col6" >-0.079727</td>
#       <td id="T_51a5c_row3_col7" class="data row3 col7" >0.390919</td>
#     </tr>
#     <tr>
#       <th id="T_51a5c_level0_row4" class="row_heading level0 row4" >MANA price (USD)</th>
#       <td id="T_51a5c_row4_col0" class="data row4 col0" >-0.101561</td>
#       <td id="T_51a5c_row4_col1" class="data row4 col1" >-0.014715</td>
#       <td id="T_51a5c_row4_col2" class="data row4 col2" >-0.101825</td>
#       <td id="T_51a5c_row4_col3" class="data row4 col3" >-0.102890</td>
#       <td id="T_51a5c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_51a5c_row4_col5" class="data row4 col5" >0.856573</td>
#       <td id="T_51a5c_row4_col6" class="data row4 col6" >0.005078</td>
#       <td id="T_51a5c_row4_col7" class="data row4 col7" >0.040340</td>
#     </tr>
#     <tr>
#       <th id="T_51a5c_level0_row5" class="row_heading level0 row5" >ETH price (USD)</th>
#       <td id="T_51a5c_row5_col0" class="data row5 col0" >-0.105718</td>
#       <td id="T_51a5c_row5_col1" class="data row5 col1" >-0.013875</td>
#       <td id="T_51a5c_row5_col2" class="data row5 col2" >-0.106019</td>
#       <td id="T_51a5c_row5_col3" class="data row5 col3" >-0.106879</td>
#       <td id="T_51a5c_row5_col4" class="data row5 col4" >0.856573</td>
#       <td id="T_51a5c_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_51a5c_row5_col6" class="data row5 col6" >0.007135</td>
#       <td id="T_51a5c_row5_col7" class="data row5 col7" >0.080171</td>
#     </tr>
#     <tr>
#       <th id="T_51a5c_level0_row6" class="row_heading level0 row6" >Fee Percentage</th>
#       <t

# %%
#save df to csv for use in another notebook
df.to_csv('DecentralandDataWearablesWithPolygon.csv')
